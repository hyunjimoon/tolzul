# %%
# Translated to .py by Marti Montesinos
# Adapted to PandasBiogeme by Michel Bierlaire
# Sun Oct 21 23:41:03 2018
# %reset
globals().clear()

import pandas as pd
import biogeme.database as db
import biogeme.biogeme as bio
import biogeme.models as models
from biogeme.expressions import Beta, DefineVariable

df = pd.read_csv("SwissMetro/swissmetro.dat",'\t')
database = db.Database("swissmetro",df)
pd.options.display.float_format = '{:.3g}'.format
globals().update(database.variables)

exclude = ((  PURPOSE   !=  1  ) * (  PURPOSE   !=  3  ) + (  CHOICE   ==  0  ))>0
database.remove(exclude)



#Parameters to be estimated
# Arguments:
#   1  Name for report. Typically, the same as the variable
#   2  Starting value
#   3  Lower bound
#   4  Upper bound
#   5  0: estimate the parameter, 1: keep it fixed
ASC_CAR	 = Beta('ASC_CAR',0,None,None,0)
ASC_SBB	 = Beta('ASC_SBB',0,None,None,1)
ASC_SM	 = Beta('ASC_SM',0,None,None,0)
B_COST	 = Beta('B_COST',0,None,None,0)
B_HE	 = Beta('B_HE',0,None,None,0)
B_TIME	 = Beta('B_TIME',0,None,None,0)

# Define here arithmetic expressions for name that are not directly 
# available from the data

CAR_AV_SP  = DefineVariable('CAR_AV_SP', CAR_AV    *  (  SP   !=  0  ),database)
SM_COST  = DefineVariable('SM_COST', SM_CO   * (  GA   ==  0  ),database)
TRAIN_AV_SP  = DefineVariable('TRAIN_AV_SP', TRAIN_AV    *  (  SP   !=  0  ),database)
TRAIN_COST  = DefineVariable('TRAIN_COST', TRAIN_CO   * (  GA   ==  0  ),database)

TRAIN_TT_SCALED = DefineVariable('TRAIN_TT_SCALED',\
                                 TRAIN_TT / 100.0,database)
TRAIN_COST_SCALED = DefineVariable('TRAIN_COST_SCALED',\
                                   TRAIN_COST / 100,database)
SM_TT_SCALED = DefineVariable('SM_TT_SCALED', SM_TT / 100.0,database)
SM_COST_SCALED = DefineVariable('SM_COST_SCALED', SM_COST / 100,database)
CAR_TT_SCALED = DefineVariable('CAR_TT_SCALED', CAR_TT / 100,database)
CAR_CO_SCALED = DefineVariable('CAR_CO_SCALED', CAR_CO / 100,database)
TRAIN_HE_SCALED = DefineVariable('TRAIN_HE_SCALED', TRAIN_HE / 100,database)
SM_HE_SCALED = DefineVariable('SM_HE_SCALED', SM_HE / 100,database)

#Utilities
Car_SP = ASC_CAR + B_TIME * CAR_TT_SCALED + B_COST * CAR_CO_SCALED
SBB_SP = ASC_SBB + B_TIME * TRAIN_TT_SCALED + B_COST * TRAIN_COST_SCALED + B_HE * TRAIN_HE_SCALED
SM_SP = ASC_SM + B_TIME * SM_TT_SCALED + B_COST * SM_COST_SCALED + B_HE * SM_HE_SCALED
V = {3: Car_SP,1: SBB_SP,2: SM_SP}
av = {3: CAR_AV_SP,1: TRAIN_AV_SP,2: SM_AV}

# The choice model is a logit, with availability conditions
logprob = models.loglogit(V,av,CHOICE)
biogeme  = bio.BIOGEME(database,logprob)
biogeme.modelName = "logit_SM_generic"
results = biogeme.estimate()
# Get the results in a pandas table
pandasResults = results.getEstimatedParameters()
print(pandasResults)
print(f"Nbr of observations: {database.getNumberOfObservations()}")
print(f"LL(0) =    {results.data.initLogLike:.3f}")
print(f"LL(beta) = {results.data.logLike:.3f}")
print(f"rho bar square = {results.data.rhoBarSquare:.3g}")
print(f"Output file: {results.data.htmlFileName}")
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y
# C:\anaconda3\envs\study\lib\site-packages\IPython\core\interactiveshell.py:3369: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#          Value  Std err  t-test  p-value  Rob. Std err  Rob. t-test  \
# ASC_CAR  0.189   0.0773    2.45   0.0144        0.0798         2.37
# ASC_SM   0.451   0.0697    6.47 9.62e-11        0.0932         4.84
# B_COST   -1.08   0.0518   -20.9        0        0.0682        -15.9
# B_HE    -0.535   0.0964   -5.55 2.79e-08        0.0983        -5.45
# B_TIME   -1.28   0.0569   -22.4        0         0.104        -12.2
#
#          Rob. p-value
# ASC_CAR        0.0177
# ASC_SM       1.32e-06
# B_COST              0
# B_HE         5.15e-08
# B_TIME              0
# Nbr of observations: 6768
# LL(0) =    -5315.386
# LL(beta) = -5315.386
# rho bar square = -0.000941
# Output file: logit_SM_generic~03.html

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   '# Translated to .py by Marti Montesinos\n# Adapted to PandasBiogeme by Michel Bierlaire\n# Sun Oct 21 23:41:03 2018\n\nimport pandas as pd\nimport biogeme.database as db\nimport biogeme.biogeme as bio\nimport biogeme.models as models\nfrom biogeme.expressions import Beta, DefineVariable\n\ndf = pd.read_csv("SwissMetro/swissmetro.dat",\'\\t\')\ndatabase = db.Database("swissmetro",df)\npd.options.display.float_format = \'{:.3g}\'.format\nglobals().update(database.variables)\n\nexclude = ((  PURPOSE   !=  1  ) * (  PURPOSE   !=  3  ) + (  CHOICE   ==  0  ))>0\ndatabase.remove(exclude)\n\n\n\n#Parameters to be estimated\n# Arguments:\n#   1  Name for report. Typically, the same as the variable\n#   2  Starting value\n#   3  Lower bound\n#   4  Upper bound\n#   5  0: estimate the parameter, 1: keep it fixed\nASC_CAR\t = Beta(\'ASC_CAR\',0,None,None,0)\nASC_SBB\t = Beta(\'ASC_SBB\',0,None,None,1)\nASC_SM\t = Beta(\'ASC_SM\',0,None,None,0)\nB_COST\t = Beta(\'B_COST\',0,None,None,0)\nB_HE\t = Beta(\'B_HE\',0,None,None,0)\nB_TIME\t = Beta(\'B_TIME\',0,None,None,0)\n\n# Define here arithmetic expressions for name that are not directly \n# available from the data\n\nCAR_AV_SP  = DefineVariable(\'CAR_AV_SP\', CAR_AV    *  (  SP   !=  0  ),database)\nSM_COST  = DefineVariable(\'SM_COST\', SM_CO   * (  GA   ==  0  ),database)\nTRAIN_AV_SP  = DefineVariable(\'TRAIN_AV_SP\', TRAIN_AV    *  (  SP   !=  0  ),database)\nTRAIN_COST  = DefineVariable(\'TRAIN_COST\', TRAIN_CO   * (  GA   ==  0  ),database)\n\nTRAIN_TT_SCALED = DefineVariable(\'TRAIN_TT_SCALED\',\\\n                                 TRAIN_TT / 100.0,database)\nTRAIN_COST_SCALED = DefineVariable(\'TRAIN_COST_SCALED\',\\\n                                   TRAIN_COST / 100,database)\nSM_TT_SCALED = DefineVariable(\'SM_TT_SCALED\', SM_TT / 100.0,database)\nSM_COST_SCALED = DefineVariable(\'SM_COST_SCALED\', SM_COST / 100,database)\nCAR_TT_SCALED = DefineVariable(\'CAR_TT_SCALED\', CAR_TT / 100,database)\nCAR_CO_SCALED = DefineVariable(\'CAR_CO_SCALED\', CAR_CO / 100,database)\nTRAIN_HE_SCALED = DefineVariable(\'TRAIN_HE_SCALED\', TRAIN_HE / 100,database)\nSM_HE_SCALED = DefineVariable(\'SM_HE_SCALED\', SM_HE / 100,database)\n\n#Utilities\nCar_SP = ASC_CAR + B_TIME * CAR_TT_SCALED + B_COST * CAR_CO_SCALED\nSBB_SP = ASC_SBB + B_TIME * TRAIN_TT_SCALED + B_COST * TRAIN_COST_SCALED + B_HE * TRAIN_HE_SCALED\nSM_SP = ASC_SM + B_TIME * SM_TT_SCALED + B_COST * SM_COST_SCALED + B_HE * SM_HE_SCALED\nV = {3: Car_SP,1: SBB_SP,2: SM_SP}\nav = {3: CAR_AV_SP,1: TRAIN_AV_SP,2: SM_AV}\n\n# The choice model is a logit, with availability conditions\nlogprob = models.loglogit(V,av,CHOICE)\nbiogeme  = bio.BIOGEME(database,logprob)\nbiogeme.modelName = "logit_SM_generic"\nresults = biogeme.estimate()\n# Get the results in a pandas table\npandasResults = results.getEstimatedParameters()\nprint(pandasResults)\nprint(f"Nbr of observations: {database.getNumberOfObservations()}")\nprint(f"LL(0) =    {results.data.initLogLike:.3f}")\nprint(f"LL(beta) = {results.data.logLike:.3f}")\nprint(f"rho bar square = {results.data.rhoBarSquare:.3g}")\nprint(f"Output file: {results.data.htmlFileName}")',
#   '# Translated to .py by Marti Montesinos\n# Adapted to PandasBiogeme by Michel Bierlaire\n# Sun Oct 21 23:41:03 2018\nget_ipython().run_line_magic(\'reset\', \'\')\nimport pandas as pd\nimport biogeme.database as db\nimport biogeme.biogeme as bio\nimport biogeme.models as models\nfrom biogeme.expressions import Beta, DefineVariable\n\ndf = pd.read_csv("SwissMetro/swissmetro.dat",\'\\t\')\ndatabase = db.Database("swissmetro",df)\npd.options.display.float_format = \'{:.3g}\'.format\nglobals().update(database.variables)\n\nexclude = ((  PURPOSE   !=  1  ) * (  PURPOSE   !=  3  ) + (  CHOICE   ==  0  ))>0\ndatabase.remove(exclude)\n\n\n\n#Parameters to be estimated\n# Arguments:\n#   1  Name for report. Typically, the same as the variable\n#   2  Starting value\n#   3  Lower bound\n#   4  Upper bound\n#   5  0: estimate the parameter, 1: keep it fixed\nASC_CAR\t = Beta(\'ASC_CAR\',0,None,None,0)\nASC_SBB\t = Beta(\'ASC_SBB\',0,None,None,1)\nASC_SM\t = Beta(\'ASC_SM\',0,None,None,0)\nB_COST\t = Beta(\'B_COST\',0,None,None,0)\nB_HE\t = Beta(\'B_HE\',0,None,None,0)\nB_TIME\t = Beta(\'B_TIME\',0,None,None,0)\n\n# Define here arithmetic expressions for name that are not directly \n# available from the data\n\nCAR_AV_SP  = DefineVariable(\'CAR_AV_SP\', CAR_AV    *  (  SP   !=  0  ),database)\nSM_COST  = DefineVariable(\'SM_COST\', SM_CO   * (  GA   ==  0  ),database)\nTRAIN_AV_SP  = DefineVariable(\'TRAIN_AV_SP\', TRAIN_AV    *  (  SP   !=  0  ),database)\nTRAIN_COST  = DefineVariable(\'TRAIN_COST\', TRAIN_CO   * (  GA   ==  0  ),database)\n\nTRAIN_TT_SCALED = DefineVariable(\'TRAIN_TT_SCALED\',\\\n                                 TRAIN_TT / 100.0,database)\nTRAIN_COST_SCALED = DefineVariable(\'TRAIN_COST_SCALED\',\\\n                                   TRAIN_COST / 100,database)\nSM_TT_SCALED = DefineVariable(\'SM_TT_SCALED\', SM_TT / 100.0,database)\nSM_COST_SCALED = DefineVariable(\'SM_COST_SCALED\', SM_COST / 100,database)\nCAR_TT_SCALED = DefineVariable(\'CAR_TT_SCALED\', CAR_TT / 100,database)\nCAR_CO_SCALED = DefineVariable(\'CAR_CO_SCALED\', CAR_CO / 100,database)\nTRAIN_HE_SCALED = DefineVariable(\'TRAIN_HE_SCALED\', TRAIN_HE / 100,database)\nSM_HE_SCALED = DefineVariable(\'SM_HE_SCALED\', SM_HE / 100,database)\n\n#Utilities\nCar_SP = ASC_CAR + B_TIME * CAR_TT_SCALED + B_COST * CAR_CO_SCALED\nSBB_SP = ASC_SBB + B_TIME * TRAIN_TT_SCALED + B_COST * TRAIN_COST_SCALED + B_HE * TRAIN_HE_SCALED\nSM_SP = ASC_SM + B_TIME * SM_TT_SCALED + B_COST * SM_COST_SCALED + B_HE * SM_HE_SCALED\nV = {3: Car_SP,1: SBB_SP,2: SM_SP}\nav = {3: CAR_AV_SP,1: TRAIN_AV_SP,2: SM_AV}\n\n# The choice model is a logit, with availability conditions\nlogprob = models.loglogit(V,av,CHOICE)\nbiogeme  = bio.BIOGEME(database,logprob)\nbiogeme.modelName = "logit_SM_generic"\nresults = biogeme.estimate()\n# Get the results in a pandas table\npandasResults = results.getEstimatedParameters()\nprint(pandasResults)\nprint(f"Nbr of observations: {database.getNumberOfObservations()}")\nprint(f"LL(0) =    {results.data.initLogLike:.3f}")\nprint(f"LL(beta) = {results.data.logLike:.3f}")\nprint(f"rho bar square = {results.data.rhoBarSquare:.3g}")\nprint(f"Output file: {results.data.htmlFileName}")',
#   'globals()'],
#  '_oh': {},
#  '_dh': [WindowsPath('C:/Users/Yuzhu/OneDrive - Massachusetts Institute of Technology/Spring_2022/1.202/HW4')],
#  'In': ['',
#   '# Translated to .py by Marti Montesinos\n# Adapted to PandasBiogeme by Michel Bierlaire\n# Sun Oct 21 23:41:03 2018\n\nimport pandas as pd\nimport biogeme.database as db\nimport biogeme.biogeme as bio\nimport biogeme.models as models\nfrom biogeme.expressions import Beta, DefineVariable\n\ndf = pd.read_csv("SwissMetro/swissmetro.dat",\'\\t\')\ndatabase = db.Database("swissmetro",df)\npd.options.display.float_format = \'{:.3g}\'.format\nglobals().update(database.variables)\n\nexclude = ((  PURPOSE   !=  1  ) * (  PURPOSE   !=  3  ) + (  CHOICE   ==  0  ))>0\ndatabase.remove(exclude)\n\n\n\n#Parameters to be estimated\n# Arguments:\n#   1  Name for report. Typically, the same as the variable\n#   2  Starting value\n#   3  Lower bound\n#   4  Upper bound\n#   5  0: estimate the parameter, 1: keep it fixed\nASC_CAR\t = Beta(\'ASC_CAR\',0,None,None,0)\nASC_SBB\t = Beta(\'ASC_SBB\',0,None,None,1)\nASC_SM\t = Beta(\'ASC_SM\',0,None,None,0)\nB_COST\t = Beta(\'B_COST\',0,None,None,0)\nB_HE\t = Beta(\'B_HE\',0,None,None,0)\nB_TIME\t = Beta(\'B_TIME\',0,None,None,0)\n\n# Define here arithmetic expressions for name that are not directly \n# available from the data\n\nCAR_AV_SP  = DefineVariable(\'CAR_AV_SP\', CAR_AV    *  (  SP   !=  0  ),database)\nSM_COST  = DefineVariable(\'SM_COST\', SM_CO   * (  GA   ==  0  ),database)\nTRAIN_AV_SP  = DefineVariable(\'TRAIN_AV_SP\', TRAIN_AV    *  (  SP   !=  0  ),database)\nTRAIN_COST  = DefineVariable(\'TRAIN_COST\', TRAIN_CO   * (  GA   ==  0  ),database)\n\nTRAIN_TT_SCALED = DefineVariable(\'TRAIN_TT_SCALED\',\\\n                                 TRAIN_TT / 100.0,database)\nTRAIN_COST_SCALED = DefineVariable(\'TRAIN_COST_SCALED\',\\\n                                   TRAIN_COST / 100,database)\nSM_TT_SCALED = DefineVariable(\'SM_TT_SCALED\', SM_TT / 100.0,database)\nSM_COST_SCALED = DefineVariable(\'SM_COST_SCALED\', SM_COST / 100,database)\nCAR_TT_SCALED = DefineVariable(\'CAR_TT_SCALED\', CAR_TT / 100,database)\nCAR_CO_SCALED = DefineVariable(\'CAR_CO_SCALED\', CAR_CO / 100,database)\nTRAIN_HE_SCALED = DefineVariable(\'TRAIN_HE_SCALED\', TRAIN_HE / 100,database)\nSM_HE_SCALED = DefineVariable(\'SM_HE_SCALED\', SM_HE / 100,database)\n\n#Utilities\nCar_SP = ASC_CAR + B_TIME * CAR_TT_SCALED + B_COST * CAR_CO_SCALED\nSBB_SP = ASC_SBB + B_TIME * TRAIN_TT_SCALED + B_COST * TRAIN_COST_SCALED + B_HE * TRAIN_HE_SCALED\nSM_SP = ASC_SM + B_TIME * SM_TT_SCALED + B_COST * SM_COST_SCALED + B_HE * SM_HE_SCALED\nV = {3: Car_SP,1: SBB_SP,2: SM_SP}\nav = {3: CAR_AV_SP,1: TRAIN_AV_SP,2: SM_AV}\n\n# The choice model is a logit, with availability conditions\nlogprob = models.loglogit(V,av,CHOICE)\nbiogeme  = bio.BIOGEME(database,logprob)\nbiogeme.modelName = "logit_SM_generic"\nresults = biogeme.estimate()\n# Get the results in a pandas table\npandasResults = results.getEstimatedParameters()\nprint(pandasResults)\nprint(f"Nbr of observations: {database.getNumberOfObservations()}")\nprint(f"LL(0) =    {results.data.initLogLike:.3f}")\nprint(f"LL(beta) = {results.data.logLike:.3f}")\nprint(f"rho bar square = {results.data.rhoBarSquare:.3g}")\nprint(f"Output file: {results.data.htmlFileName}")',
#   '# Translated to .py by Marti Montesinos\n# Adapted to PandasBiogeme by Michel Bierlaire\n# Sun Oct 21 23:41:03 2018\nget_ipython().run_line_magic(\'reset\', \'\')\nimport pandas as pd\nimport biogeme.database as db\nimport biogeme.biogeme as bio\nimport biogeme.models as models\nfrom biogeme.expressions import Beta, DefineVariable\n\ndf = pd.read_csv("SwissMetro/swissmetro.dat",\'\\t\')\ndatabase = db.Database("swissmetro",df)\npd.options.display.float_format = \'{:.3g}\'.format\nglobals().update(database.variables)\n\nexclude = ((  PURPOSE   !=  1  ) * (  PURPOSE   !=  3  ) + (  CHOICE   ==  0  ))>0\ndatabase.remove(exclude)\n\n\n\n#Parameters to be estimated\n# Arguments:\n#   1  Name for report. Typically, the same as the variable\n#   2  Starting value\n#   3  Lower bound\n#   4  Upper bound\n#   5  0: estimate the parameter, 1: keep it fixed\nASC_CAR\t = Beta(\'ASC_CAR\',0,None,None,0)\nASC_SBB\t = Beta(\'ASC_SBB\',0,None,None,1)\nASC_SM\t = Beta(\'ASC_SM\',0,None,None,0)\nB_COST\t = Beta(\'B_COST\',0,None,None,0)\nB_HE\t = Beta(\'B_HE\',0,None,None,0)\nB_TIME\t = Beta(\'B_TIME\',0,None,None,0)\n\n# Define here arithmetic expressions for name that are not directly \n# available from the data\n\nCAR_AV_SP  = DefineVariable(\'CAR_AV_SP\', CAR_AV    *  (  SP   !=  0  ),database)\nSM_COST  = DefineVariable(\'SM_COST\', SM_CO   * (  GA   ==  0  ),database)\nTRAIN_AV_SP  = DefineVariable(\'TRAIN_AV_SP\', TRAIN_AV    *  (  SP   !=  0  ),database)\nTRAIN_COST  = DefineVariable(\'TRAIN_COST\', TRAIN_CO   * (  GA   ==  0  ),database)\n\nTRAIN_TT_SCALED = DefineVariable(\'TRAIN_TT_SCALED\',\\\n                                 TRAIN_TT / 100.0,database)\nTRAIN_COST_SCALED = DefineVariable(\'TRAIN_COST_SCALED\',\\\n                                   TRAIN_COST / 100,database)\nSM_TT_SCALED = DefineVariable(\'SM_TT_SCALED\', SM_TT / 100.0,database)\nSM_COST_SCALED = DefineVariable(\'SM_COST_SCALED\', SM_COST / 100,database)\nCAR_TT_SCALED = DefineVariable(\'CAR_TT_SCALED\', CAR_TT / 100,database)\nCAR_CO_SCALED = DefineVariable(\'CAR_CO_SCALED\', CAR_CO / 100,database)\nTRAIN_HE_SCALED = DefineVariable(\'TRAIN_HE_SCALED\', TRAIN_HE / 100,database)\nSM_HE_SCALED = DefineVariable(\'SM_HE_SCALED\', SM_HE / 100,database)\n\n#Utilities\nCar_SP = ASC_CAR + B_TIME * CAR_TT_SCALED + B_COST * CAR_CO_SCALED\nSBB_SP = ASC_SBB + B_TIME * TRAIN_TT_SCALED + B_COST * TRAIN_COST_SCALED + B_HE * TRAIN_HE_SCALED\nSM_SP = ASC_SM + B_TIME * SM_TT_SCALED + B_COST * SM_COST_SCALED + B_HE * SM_HE_SCALED\nV = {3: Car_SP,1: SBB_SP,2: SM_SP}\nav = {3: CAR_AV_SP,1: TRAIN_AV_SP,2: SM_AV}\n\n# The choice model is a logit, with availability conditions\nlogprob = models.loglogit(V,av,CHOICE)\nbiogeme  = bio.BIOGEME(database,logprob)\nbiogeme.modelName = "logit_SM_generic"\nresults = biogeme.estimate()\n# Get the results in a pandas table\npandasResults = results.getEstimatedParameters()\nprint(pandasResults)\nprint(f"Nbr of observations: {database.getNumberOfObservations()}")\nprint(f"LL(0) =    {results.data.initLogLike:.3f}")\nprint(f"LL(beta) = {results.data.logLike:.3f}")\nprint(f"rho bar square = {results.data.rhoBarSquare:.3g}")\nprint(f"Output file: {results.data.htmlFileName}")',
#   'globals()'],
#  'Out': {},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x000001BE2A003490>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x1be2a003b50>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x1be2a003b50>,
#  'pd': <module 'pandas' from 'C:\\anaconda3\\envs\\study\\lib\\site-packages\\pandas\\__init__.py'>,
#  'db': <module 'biogeme.database' from 'C:\\anaconda3\\envs\\study\\lib\\site-packages\\biogeme\\database.py'>,
#  'bio': <module 'biogeme.biogeme' from 'C:\\anaconda3\\envs\\study\\lib\\site-packages\\biogeme\\biogeme.py'>,
#  'models': <module 'biogeme.models' from 'C:\\anaconda3\\envs\\study\\lib\\site-packages\\biogeme\\models.py'>,
#  'Beta': biogeme.expressions.Beta,
#  'DefineVariable': biogeme.expressions.DefineVariable,
#  'df':       GROUP  SURVEY  SP   ID  PURPOSE  FIRST  TICKET  WHO  LUGGAGE  AGE  ...  \
#  0         2       0   1    1        1      0       1    1        0    3  ...
#  1         2       0   1    1        1      0       1    1        0    3  ...
#  2         2       0   1    1        1      0       1    1        0    3  ...
#  3         2       0   1    1        1      0       1    1        0    3  ...
#  4         2       0   1    1        1      0       1    1        0    3  ...
#  ...     ...     ...  ..  ...      ...    ...     ...  ...      ...  ...  ...
#  8446      3       1   1  939        3      1       7    3        1    5  ...
#  8447      3       1   1  939        3      1       7    3        1    5  ...
#  8448      3       1   1  939        3      1       7    3        1    5  ...
#  8449      3       1   1  939        3      1       7    3        1    5  ...
#  8450      3       1   1  939        3      1       7    3        1    5  ...
#
#        TRAIN_AV_SP  TRAIN_COST  TRAIN_TT_SCALED  TRAIN_COST_SCALED  \
#  0               1          48             1.12               0.48
#  1               1          48             1.03               0.48
#  2               1          48              1.3               0.48
#  3               1          40             1.03                0.4
#  4               1          36              1.3               0.36
#  ...           ...         ...              ...                ...
#  8446            1          13             1.08               0.13
#  8447            1          12             1.08               0.12
#  8448            1          16             1.08               0.16
#  8449            1          16             1.28               0.16
#  8450            1          13             1.08               0.13
#
#        SM_TT_SCALED  SM_COST_SCALED  CAR_TT_SCALED  CAR_CO_SCALED  \
#  0             0.63            0.52           1.17           0.65
#  1              0.6            0.49           1.17           0.84
#  2             0.67            0.58           1.17           0.52
#  3             0.63            0.52           0.72           0.52
#  4             0.63            0.42            0.9           0.84
#  ...            ...             ...            ...            ...
#  8446           0.5            0.17            1.3           0.64
#  8447          0.53            0.16            0.8            0.8
#  8448           0.5            0.16            0.8           0.64
#  8449          0.53            0.17            0.8           1.04
#  8450          0.53            0.21              1            0.8
#
#        TRAIN_HE_SCALED  SM_HE_SCALED
#  0                 1.2           0.2
#  1                 0.3           0.1
#  2                 0.6           0.3
#  3                 0.3           0.2
#  4                 0.6           0.2
#  ...               ...           ...
#  8446              0.3           0.3
#  8447              0.3           0.1
#  8448              0.6           0.2
#  8449              0.3           0.3
#  8450              0.6           0.3
#
#  [6768 rows x 40 columns],
#  'database': <biogeme.database.Database at 0x1be2a04c7c0>,
#  'GROUP': GROUP,
#  'SURVEY': SURVEY,
#  'SP': SP,
#  'ID': ID,
#  'PURPOSE': PURPOSE,
#  'FIRST': FIRST,
#  'TICKET': TICKET,
#  'WHO': WHO,
#  'LUGGAGE': LUGGAGE,
#  'AGE': AGE,
#  'MALE': MALE,
#  'INCOME': INCOME,
#  'GA': GA,
#  'ORIGIN': ORIGIN,
#  'DEST': DEST,
#  'TRAIN_AV': TRAIN_AV,
#  'CAR_AV': CAR_AV,
#  'SM_AV': SM_AV,
#  'TRAIN_TT': TRAIN_TT,
#  'TRAIN_CO': TRAIN_CO,
#  'TRAIN_HE': TRAIN_HE,
#  'SM_TT': SM_TT,
#  'SM_CO': SM_CO,
#  'SM_HE': SM_HE,
#  'SM_SEATS': SM_SEATS,
#  'CAR_TT': CAR_TT,
#  'CAR_CO': CAR_CO,
#  'CHOICE': CHOICE,
#  'exclude': ((((PURPOSE != `1`) * (PURPOSE != `3`)) + (CHOICE == `0`)) > `0`),
#  'ASC_CAR': ASC_CAR(0.18916607958381332),
#  'ASC_SBB': ASC_SBB(0),
#  'ASC_SM': ASC_SM(0.4510088562440911),
#  'B_COST': B_COST(-1.0846638923476113),
#  'B_HE': B_HE(-0.5353518737120729),
#  'B_TIME': B_TIME(-1.2767847095664377),
#  'CAR_AV_SP': CAR_AV_SP,
#  'SM_COST': SM_COST,
#  'TRAIN_AV_SP': TRAIN_AV_SP,
#  'TRAIN_COST': TRAIN_COST,
#  'TRAIN_TT_SCALED': TRAIN_TT_SCALED,
#  'TRAIN_COST_SCALED': TRAIN_COST_SCALED,
#  'SM_TT_SCALED': SM_TT_SCALED,
#  'SM_COST_SCALED': SM_COST_SCALED,
#  'CAR_TT_SCALED': CAR_TT_SCALED,
#  'CAR_CO_SCALED': CAR_CO_SCALED,
#  'TRAIN_HE_SCALED': TRAIN_HE_SCALED,
#  'SM_HE_SCALED': SM_HE_SCALED,
#  'Car_SP': ((ASC_CAR(0.18916607958381332) + (B_TIME(-1.2767847095664377) * CAR_TT_SCALED)) + (B_COST(-1.0846638923476113) * CAR_CO_SCALED)),
#  'SBB_SP': (((ASC_SBB(0) + (B_TIME(-1.2767847095664377) * TRAIN_TT_SCALED)) + (B_COST(-1.0846638923476113) * TRAIN_COST_SCALED)) + (B_HE(-0.5353518737120729) * TRAIN_HE_SCALED)),
#  'SM_SP': (((ASC_SM(0.4510088562440911) + (B_TIME(-1.2767847095664377) * SM_TT_SCALED)) + (B_COST(-1.0846638923476113) * SM_COST_SCALED)) + (B_HE(-0.5353518737120729) * SM_HE_SCALED)),
#  'V': {3: ((ASC_CAR(0.18916607958381332) + (B_TIME(-1.2767847095664377) * CAR_TT_SCALED)) + (B_COST(-1.0846638923476113) * CAR_CO_SCALED)),
#   1: (((ASC_SBB(0) + (B_TIME(-1.2767847095664377) * TRAIN_TT_SCALED)) + (B_COST(-1.0846638923476113) * TRAIN_COST_SCALED)) + (B_HE(-0.5353518737120729) * TRAIN_HE_SCALED)),
#   2: (((ASC_SM(0.4510088562440911) + (B_TIME(-1.2767847095664377) * SM_TT_SCALED)) + (B_COST(-1.0846638923476113) * SM_COST_SCALED)) + (B_HE(-0.5353518737120729) * SM_HE_SCALED))},
#  'av': {3: CAR_AV_SP, 1: TRAIN_AV_SP, 2: SM_AV},
#  'logprob': _bioLogLogit(3:((ASC_CAR(0.18916607958381332) + (B_TIME(-1.2767847095664377) * CAR_TT_SCALED)) + (B_COST(-1.0846638923476113) * CAR_CO_SCALED)), 1:(((ASC_SBB(0) + (B_TIME(-1.2767847095664377) * TRAIN_TT_SCALED)) + (B_COST(-1.0846638923476113) * TRAIN_COST_SCALED)) + (B_HE(-0.5353518737120729) * TRAIN_HE_SCALED)), 2:(((ASC_SM(0.4510088562440911) + (B_TIME(-1.2767847095664377) * SM_TT_SCALED)) + (B_COST(-1.0846638923476113) * SM_COST_SCALED)) + (B_HE(-0.5353518737120729) * SM_HE_SCALED))),
#  'biogeme': <biogeme.biogeme.BIOGEME at 0x1be2a090bb0>,
#  'results': <biogeme.results.bioResults at 0x1be2a0861f0>,
#  'pandasResults':          Value  Std err  t-test  p-value  Rob. Std err  Rob. t-test  \
#  ASC_CAR  0.189   0.0773    2.45   0.0144        0.0798         2.37
#  ASC_SM   0.451   0.0697    6.47 9.62e-11        0.0932         4.84
#  B_COST   -1.08   0.0518   -20.9        0        0.0682        -15.9
#  B_HE    -0.535   0.0964   -5.55 2.79e-08        0.0983        -5.45
#  B_TIME   -1.28   0.0569   -22.4        0         0.104        -12.2
#
#           Rob. p-value
#  ASC_CAR        0.0177
#  ASC_SM       1.32e-06
#  B_COST              0
#  B_HE         5.15e-08
#  B_TIME              0  ,
#  '_i': '# Translated to .py by Marti Montesinos\n# Adapted to PandasBiogeme by Michel Bierlaire\n# Sun Oct 21 23:41:03 2018\n%reset\nimport pandas as pd\nimport biogeme.database as db\nimport biogeme.biogeme as bio\nimport biogeme.models as models\nfrom biogeme.expressions import Beta, DefineVariable\n\ndf = pd.read_csv("SwissMetro/swissmetro.dat",\'\\t\')\ndatabase = db.Database("swissmetro",df)\npd.options.display.float_format = \'{:.3g}\'.format\nglobals().update(database.variables)\n\nexclude = ((  PURPOSE   !=  1  ) * (  PURPOSE   !=  3  ) + (  CHOICE   ==  0  ))>0\ndatabase.remove(exclude)\n\n\n\n#Parameters to be estimated\n# Arguments:\n#   1  Name for report. Typically, the same as the variable\n#   2  Starting value\n#   3  Lower bound\n#   4  Upper bound\n#   5  0: estimate the parameter, 1: keep it fixed\nASC_CAR\t = Beta(\'ASC_CAR\',0,None,None,0)\nASC_SBB\t = Beta(\'ASC_SBB\',0,None,None,1)\nASC_SM\t = Beta(\'ASC_SM\',0,None,None,0)\nB_COST\t = Beta(\'B_COST\',0,None,None,0)\nB_HE\t = Beta(\'B_HE\',0,None,None,0)\nB_TIME\t = Beta(\'B_TIME\',0,None,None,0)\n\n# Define here arithmetic expressions for name that are not directly \n# available from the data\n\nCAR_AV_SP  = DefineVariable(\'CAR_AV_SP\', CAR_AV    *  (  SP   !=  0  ),database)\nSM_COST  = DefineVariable(\'SM_COST\', SM_CO   * (  GA   ==  0  ),database)\nTRAIN_AV_SP  = DefineVariable(\'TRAIN_AV_SP\', TRAIN_AV    *  (  SP   !=  0  ),database)\nTRAIN_COST  = DefineVariable(\'TRAIN_COST\', TRAIN_CO   * (  GA   ==  0  ),database)\n\nTRAIN_TT_SCALED = DefineVariable(\'TRAIN_TT_SCALED\',\\\n                                 TRAIN_TT / 100.0,database)\nTRAIN_COST_SCALED = DefineVariable(\'TRAIN_COST_SCALED\',\\\n                                   TRAIN_COST / 100,database)\nSM_TT_SCALED = DefineVariable(\'SM_TT_SCALED\', SM_TT / 100.0,database)\nSM_COST_SCALED = DefineVariable(\'SM_COST_SCALED\', SM_COST / 100,database)\nCAR_TT_SCALED = DefineVariable(\'CAR_TT_SCALED\', CAR_TT / 100,database)\nCAR_CO_SCALED = DefineVariable(\'CAR_CO_SCALED\', CAR_CO / 100,database)\nTRAIN_HE_SCALED = DefineVariable(\'TRAIN_HE_SCALED\', TRAIN_HE / 100,database)\nSM_HE_SCALED = DefineVariable(\'SM_HE_SCALED\', SM_HE / 100,database)\n\n#Utilities\nCar_SP = ASC_CAR + B_TIME * CAR_TT_SCALED + B_COST * CAR_CO_SCALED\nSBB_SP = ASC_SBB + B_TIME * TRAIN_TT_SCALED + B_COST * TRAIN_COST_SCALED + B_HE * TRAIN_HE_SCALED\nSM_SP = ASC_SM + B_TIME * SM_TT_SCALED + B_COST * SM_COST_SCALED + B_HE * SM_HE_SCALED\nV = {3: Car_SP,1: SBB_SP,2: SM_SP}\nav = {3: CAR_AV_SP,1: TRAIN_AV_SP,2: SM_AV}\n\n# The choice model is a logit, with availability conditions\nlogprob = models.loglogit(V,av,CHOICE)\nbiogeme  = bio.BIOGEME(database,logprob)\nbiogeme.modelName = "logit_SM_generic"\nresults = biogeme.estimate()\n# Get the results in a pandas table\npandasResults = results.getEstimatedParameters()\nprint(pandasResults)\nprint(f"Nbr of observations: {database.getNumberOfObservations()}")\nprint(f"LL(0) =    {results.data.initLogLike:.3f}")\nprint(f"LL(beta) = {results.data.logLike:.3f}")\nprint(f"rho bar square = {results.data.rhoBarSquare:.3g}")\nprint(f"Output file: {results.data.htmlFileName}")',
#  '_ii': '# Translated to .py by Marti Montesinos\n# Adapted to PandasBiogeme by Michel Bierlaire\n# Sun Oct 21 23:41:03 2018\n\nimport pandas as pd\nimport biogeme.database as db\nimport biogeme.biogeme as bio\nimport biogeme.models as models\nfrom biogeme.expressions import Beta, DefineVariable\n\ndf = pd.read_csv("SwissMetro/swissmetro.dat",\'\\t\')\ndatabase = db.Database("swissmetro",df)\npd.options.display.float_format = \'{:.3g}\'.format\nglobals().update(database.variables)\n\nexclude = ((  PURPOSE   !=  1  ) * (  PURPOSE   !=  3  ) + (  CHOICE   ==  0  ))>0\ndatabase.remove(exclude)\n\n\n\n#Parameters to be estimated\n# Arguments:\n#   1  Name for report. Typically, the same as the variable\n#   2  Starting value\n#   3  Lower bound\n#   4  Upper bound\n#   5  0: estimate the parameter, 1: keep it fixed\nASC_CAR\t = Beta(\'ASC_CAR\',0,None,None,0)\nASC_SBB\t = Beta(\'ASC_SBB\',0,None,None,1)\nASC_SM\t = Beta(\'ASC_SM\',0,None,None,0)\nB_COST\t = Beta(\'B_COST\',0,None,None,0)\nB_HE\t = Beta(\'B_HE\',0,None,None,0)\nB_TIME\t = Beta(\'B_TIME\',0,None,None,0)\n\n# Define here arithmetic expressions for name that are not directly \n# available from the data\n\nCAR_AV_SP  = DefineVariable(\'CAR_AV_SP\', CAR_AV    *  (  SP   !=  0  ),database)\nSM_COST  = DefineVariable(\'SM_COST\', SM_CO   * (  GA   ==  0  ),database)\nTRAIN_AV_SP  = DefineVariable(\'TRAIN_AV_SP\', TRAIN_AV    *  (  SP   !=  0  ),database)\nTRAIN_COST  = DefineVariable(\'TRAIN_COST\', TRAIN_CO   * (  GA   ==  0  ),database)\n\nTRAIN_TT_SCALED = DefineVariable(\'TRAIN_TT_SCALED\',\\\n                                 TRAIN_TT / 100.0,database)\nTRAIN_COST_SCALED = DefineVariable(\'TRAIN_COST_SCALED\',\\\n                                   TRAIN_COST / 100,database)\nSM_TT_SCALED = DefineVariable(\'SM_TT_SCALED\', SM_TT / 100.0,database)\nSM_COST_SCALED = DefineVariable(\'SM_COST_SCALED\', SM_COST / 100,database)\nCAR_TT_SCALED = DefineVariable(\'CAR_TT_SCALED\', CAR_TT / 100,database)\nCAR_CO_SCALED = DefineVariable(\'CAR_CO_SCALED\', CAR_CO / 100,database)\nTRAIN_HE_SCALED = DefineVariable(\'TRAIN_HE_SCALED\', TRAIN_HE / 100,database)\nSM_HE_SCALED = DefineVariable(\'SM_HE_SCALED\', SM_HE / 100,database)\n\n#Utilities\nCar_SP = ASC_CAR + B_TIME * CAR_TT_SCALED + B_COST * CAR_CO_SCALED\nSBB_SP = ASC_SBB + B_TIME * TRAIN_TT_SCALED + B_COST * TRAIN_COST_SCALED + B_HE * TRAIN_HE_SCALED\nSM_SP = ASC_SM + B_TIME * SM_TT_SCALED + B_COST * SM_COST_SCALED + B_HE * SM_HE_SCALED\nV = {3: Car_SP,1: SBB_SP,2: SM_SP}\nav = {3: CAR_AV_SP,1: TRAIN_AV_SP,2: SM_AV}\n\n# The choice model is a logit, with availability conditions\nlogprob = models.loglogit(V,av,CHOICE)\nbiogeme  = bio.BIOGEME(database,logprob)\nbiogeme.modelName = "logit_SM_generic"\nresults = biogeme.estimate()\n# Get the results in a pandas table\npandasResults = results.getEstimatedParameters()\nprint(pandasResults)\nprint(f"Nbr of observations: {database.getNumberOfObservations()}")\nprint(f"LL(0) =    {results.data.initLogLike:.3f}")\nprint(f"LL(beta) = {results.data.logLike:.3f}")\nprint(f"rho bar square = {results.data.rhoBarSquare:.3g}")\nprint(f"Output file: {results.data.htmlFileName}")',
#  '_iii': '',
#  '_i3': 'globals()'}
