# %%
import numpy as np
import pandas as pd
from itertools import cycle, islice
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       2 import pandas as pd
#       3 from itertools import cycle, islice
# ----> 4 my_colors = list(islice(cycle([ '#de796e', '#5eae76']), None, len(df)))
#
# NameError: name 'df' is not defined

# %%
my_colors = list(islice(cycle([ '#de796e', '#5eae76']), None, len(df)))
df.groupby("cap_tightness").mean().loc[:, ["solvetime1", "solvetime2"]].plot.bar(color = my_colors)
# Out:
# <Axes: xlabel='cap_tightness'>

# %%
df = pd.read_csv("lst1.csv")
df = df.drop(columns=["L"])
df_tight = df[df["cap_tightness"]==1]
df_loose = df[df["cap_tightness"]==0]
df_loose.groupby(["S", "T"]).mean().loc[:, ["solvetime1", "solvetime2"]].plot.bar(color = my_colors)
df_tight.groupby(["S", "T"]).mean().loc[:, ["solvetime1", "solvetime2"]].plot.bar(color = my_colors)
# Out:
# <Axes: xlabel='S,T'>

# %%
df_loose.groupby(["S", "T"]).mean().loc[:, ["buildtime1", "buildtime2"]].plot.bar(color = my_colors)
df_tight.groupby(["S", "T"]).mean().loc[:, ["buildtime1", "buildtime2"]].plot.bar(color = my_colors)
# Out:
# <Axes: xlabel='S,T'>

# %%
df = pd.read_csv("lst1.csv")
df = df.drop(columns=["L"])
df.groupby("cap_tightness").mean().loc[:, ["solvetime1", "solvetime2"]]
# Out:
#                solvetime1  solvetime2
# cap_tightness
# 0               10.888359   20.738235
# 1                9.374697   13.306330

# %%
df2 = pd.read_csv("lst2.csv")

# %%
df = pd.read_csv("lst2.csv")
df = df.drop(columns=["L"])
df_tight = df[df["cap_tightness"]==1]
df_loose = df[df["cap_tightness"]==0.5]
df_loose.groupby(["S", "T"]).mean().loc[:, ["solvetime1", "solvetime2"]].plot.bar(color = my_colors)
df_tight.groupby(["S", "T"]).mean().loc[:, ["solvetime1", "solvetime2"]].plot.bar(color = my_colors)

df_loose.groupby(["S", "T"]).mean().loc[:, ["buildtime1", "buildtime2"]].plot.bar(color = my_colors)
df_tight.groupby(["S", "T"]).mean().loc[:, ["buildtime1", "buildtime2"]].plot.bar(color = my_colors)
# Out:
# <Axes: xlabel='S,T'>
